# %%
using Plots

# %%
include("/home/raullima/Documentos/Git/SquareSort/src/sort.jl")
# Out:
# Main.SquareSort

# %%
using Random

# %%
y = [0.141124, 0.000028, 0.000162, 0.001825, 0.021864, 0.370814, 4.424494]
x = [10, 100, 1000, 10000, 100000, 1000000, 10000000]
# Out:
# 7-element Vector{Int64}:
#        10
#       100
#      1000
#     10000
#    100000
#   1000000
#  10000000

# %%
p1 = plot(x, y, title="Tempo de Execução", xlabel="Tamanho da Entrada", ylabel="Tempo Gasto para Resolução")

# %%
savefig(p1, "/home/raullima/Documentos/Git/SquareSort/figures/sqrtsort!.png")

# %%
p2 = plot(x, [0.218443, 0.260561, 0.004885, 0.125436, 2.993587, 68.228278, 1179.790976], title="Tempo de Execução", xlabel="Tamanho da Entrada", ylabel="Tempo Gasto para Resolução")

# %%
savefig(p2, "/home/raullima/Documentos/Git/SquareSort/figures/sqrtsort.png")

# %%
p3 = plot(x, [[0.218443, 0.260561, 0.004885, 0.125436, 2.993587, 68.228278, 1179.790976], y], title="Tempo de Execução", xlabel="Tamanho da Entrada", ylabel="Tempo Gasto para Resolução")

# %%
savefig(p3, "/home/raullima/Documentos/Git/SquareSort/figures/comparação_sqrtsortwithsqrtsort!.png")

# %%
p4 = plot!(p1, p2)

# %%
savefig(p4, "/home/raullima/Documentos/Git/SquareSort/figures/sqrtsortandsqrt!.png")
